# %%
documents = [
    {"type": "passport", "number": "2207 876234", "name": "Василий Гупкин"},
    {"type": "invoice", "number": "11-2", "name": "Геннадий Покемонов"},
    {"type": "insurance", "number": "10006", "name": "Аристарх Павлов"}
]

def find_owner_by_number(doc_number):
    for doc in documents:
        if doc["number"] == doc_number:
            return doc["name"]
    return None

def main():
    while True:
        command = input("Введите команду: ").strip().lower()
        if command == 'p':
            doc_number = input("Введите номер документа: ").strip()
            owner = find_owner_by_number(doc_number)
            if owner:
                print(f"Результат:\nВладелец документа: {owner}")
            else:
                print("Результат:\nДокумент с таким номером не найден.")
        elif command == 'q':
            print("Выход из программы.")
            break
        else:
            print("Неизвестная команда. Введите 'p' для поиска владельца или 'q' для выхода.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Результат:
# Владелец документа: Аристарх Павлов
# Неизвестная команда. Введите 'p' для поиска владельца или 'q' для выхода.
# Неизвестная команда. Введите 'p' для поиска владельца или 'q' для выхода.
# Выход из программы.
